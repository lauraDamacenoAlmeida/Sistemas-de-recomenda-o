# %%
import pandas as pd
from math import sqrt
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_filmes = pd.read_csv('data/movies.csv')
df_notas = pd.read_csv('data/ratings.csv')

# %%
df_filmes.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
#Usando Regex eu consigo separar o ano do titulo do filme
df_filmes['year'] = df_filmes.title.str.extract('(\(\d\d\d\d\))',expand=False)
#remover os parenteses
df_filmes['year'] = df_filmes.year.str.extract('(\d\d\d\d)',expand=False)
#Removendo o ano do filme
df_filmes['title'] = df_filmes.title.str.replace('(\(\d\d\d\d\))', '')
#Aplicando a função strip para remover qualquer caracter em branco
df_filmes['title'] = df_filmes['title'].apply(lambda x: x.strip())
df_filmes.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %% [markdown]
# Vamos remover o genero, pois ele não é necessário nesse tipo de sistema de recomendação

# %%
df_filmes = df_filmes.drop('genres',1)

# %%
df_filmes.head()
# Out:
#    movieId                        title  year
# 0        1                    Toy Story  1995
# 1        2                      Jumanji  1995
# 2        3             Grumpier Old Men  1995
# 3        4            Waiting to Exhale  1995
# 4        5  Father of the Bride Part II  1995

# %%
df_notas.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
df_notas = df_notas.drop('timestamp',1)

# %%
df_notas.head()
# Out:
#    userId  movieId  rating
# 0       1        1     4.0
# 1       1        3     4.0
# 2       1        6     4.0
# 3       1       47     5.0
# 4       1       50     5.0

# %% [markdown]
# ## Filtragem colaborativa

# %% [markdown]
# É conhecida como filtragem Usuário-Usuário. Como o proprio nome diz, esta tecnica usa outros usuários para recomendar itens ao usuário de entrada.
# Tenta encontrar usuário com gostos parecidos como entrada e então recomenda itens que você possa gostar.
#
# Há varios métodos para encontrar a similaridade( mesmo alguns usando técnicas de ML) e oque foi ensinado é baseado na função de Correlação de Pearson.

# %% [markdown]
# O processo para criar um sistema de recomendação baseado no usuário é o seguinte:
#     1. Selecione um usuário com os filmes que o usuário assistiu.
#     2. Baseado em sua classificação para filmes, encontre os principais vizinhos X.
#     3. Obter o registro do filme assistido do usuário para cada vizinho.
#     4. Calcular a pontuação de similaridade usando a formula.
#     5. Recomende os itens com a maior pontuação.

# %%
userInput = [
            {'title':'Breakfast Club, The', 'rating':5},
            {'title':'Toy Story', 'rating':3.5},
            {'title':'Jumanji', 'rating':2},
            {'title':"Pulp Fiction", 'rating':5},
            {'title':'Akira', 'rating':4.5}
         ] 
inputMovies = pd.DataFrame(userInput)
inputMovies
# Out:
#    rating                title
# 0     5.0  Breakfast Club, The
# 1     3.5            Toy Story
# 2     2.0              Jumanji
# 3     5.0         Pulp Fiction
# 4     4.5                Akira

# %%
#Filtrar os filmes pelo titulo
inputId = df_filmes[df_filmes['title'].isin(inputMovies['title'].tolist())]
inputId
# Out:
#       movieId                title  year
# 0           1            Toy Story  1995
# 1           2              Jumanji  1995
# 257       296         Pulp Fiction  1994
# 973      1274                Akira  1988
# 1445     1968  Breakfast Club, The  1985

# %%
#Então mesclá-lo para que possamos obter o movieId. Está implicitamente mesclando-o pelo título.
inputMovies = pd.merge(inputId, inputMovies)
inputMovies
# Out:
#    movieId                title  year  rating
# 0        1            Toy Story  1995     3.5
# 1        2              Jumanji  1995     2.0
# 2      296         Pulp Fiction  1994     5.0
# 3     1274                Akira  1988     4.5
# 4     1968  Breakfast Club, The  1985     5.0

# %%
#Retirar oque não preciso
inputMovies = inputMovies.drop('year', 1)
inputMovies
# Out:
#    movieId                title  rating
# 0        1            Toy Story     3.5
# 1        2              Jumanji     2.0
# 2      296         Pulp Fiction     5.0
# 3     1274                Akira     4.5
# 4     1968  Breakfast Club, The     5.0

# %%
#Filtrando usuários que assistiram a filmes que a entrada assistiu e armazenando
userSubset = df_notas[df_notas['movieId'].isin(inputMovies['movieId'].tolist())]
userSubset.head()
# Out:
#      userId  movieId  rating
# 0         1        1     4.0
# 16        1      296     3.0
# 320       4      296     1.0
# 422       4     1968     4.0
# 516       5        1     4.0

# %%
#Groupby cria vários subframes de dados em que todos eles têm o mesmo valor na coluna especificada como o parâmetro
userSubsetGroup = userSubset.groupby(['userId'])

# %%
#Posso filtrar pela ID do usuário, neste caso eu to pegando todos os filmes do usuário com a ID 15
userSubsetGroup.get_group(608)
# Out:
#        userId  movieId  rating
# 98666     608        1     2.5
# 98667     608        2     2.0
# 98723     608      296     5.0
# 98882     608     1274     4.0
# 98980     608     1968     4.0

# %%
userSubsetGroup.groups
# Out:
# {1: Int64Index([0, 16], dtype='int64'),
#  4: Int64Index([320, 422], dtype='int64'),
#  5: Int64Index([516, 533], dtype='int64'),
#  6: Int64Index([560, 692], dtype='int64'),
#  7: Int64Index([874], dtype='int64'),
#  8: Int64Index([1026, 1049], dtype='int64'),
#  10: Int64Index([1119], dtype='int64'),
#  14: Int64Index([1403], dtype='int64'),
#  15: Int64Index([1434, 1442], dtype='int64'),
#  16: Int64Index([1575], dtype='int64'),
#  17: Int64Index([1667, 1676], dtype='int64'),
#  18: Int64Index([1772, 1773, 1796], dtype='int64'),
#  19: Int64Index([2274, 2275, 2629], dtype='int64'),
#  20: Int64Index([2977], dtype='int64'),
#  21: Int64Index([3219, 3220, 3231], dtype='int64'),
#  23: Int64Index([3789, 3835], dtype='int64'),
#  24: Int64Index([3907], dtype='int64'),
#  26: Int64Index([4048], dtype='int64'),
#  27: Int64Index([4059, 4060], dtype='int64'),
#  28: Int64Index([4215], dtype='int64'),
#  29: Int64Index([4768], dtype='int64'),
#  31: Int64Index([4879], dtype='int64'),
#  32: Int64Index([4929, 4961], dtype='int64'),
#  33: Int64Index([5031, 5059], dtype='int64'),
#  37: Int64Index([5361], dtype='int64'),
#  38: Int64Index([5407], dtype='int64'),
#  39: Int64Index([5459, 5517], dtype='int64'),
#  40: Int64Index([5555, 5608], dtype='int64'),
#  41: Int64Index([5664], dtype='int64'),
#  42: Int64Index([5917, 6087], dtype='int64'),
#  43: Int64Index([6315, 6360], dtype='int64'),
#  44: Int64Index([6429], dtype='int64'),
#  45: Int64Index([6477, 6511, 6662], dtype='int64'),
#  46: Int64Index([6876], dtype='int64'),
#  47: Int64Index([6945], dtype='int64'),
#  50: Int64Index([7112, 7116, 7158, 7175], dtype='int64'),
#  51: Int64Index([7422], dtype='int64'),
#  54: Int64Index([7931, 7943], dtype='int64'),
#  56: Int64Index([8009], dtype='int64'),
#  57: Int64Index([8035, 8071, 8230, 8321], dtype='int64'),
#  227: Int64Index([33559], dtype='int64'),
#  229: Int64Index([33670, 33693], dtype='int64'),
#  230: Int64Index([33735, 33796], dtype='int64'),
#  231: Int64Index([33875], dtype='int64'),
#  232: Int64Index([33898, 33899, 33913], dtype='int64'),
#  233: Int64Index([34760, 34765], dtype='int64'),
#  234: Int64Index([34910], dtype='int64'),
#  235: Int64Index([35133], dtype='int64'),
#  239: Int64Index([35301, 35321], dtype='int64'),
#  240: Int64Index([35580, 35581, 35631], dtype='int64'),
#  241: Int64Index([35711], dtype='int64'),
#  242: Int64Index([35800], dtype='int64'),
#  246: Int64Index([35979], dtype='int64'),
#  247: Int64Index([36173, 36182], dtype='int64'),
#  249: Int64Index([36374, 36375, 36398], dtype='int64'),
#  251: Int64Index([37450], dtype='int64'),
#  252: Int64Index([37470], dtype='int64'),
#  254: Int64Index([37555, 37565], dtype='int64'),
#  259: Int64Index([37945], dtype='int64'),
#  260: Int64Index([37984, 38014], dtype='int64'),
#  261: Int64Index([38130], dtype='int64'),
#  262: Int64Index([38208], dtype='int64'),
#  263: Int64Index([38236, 38251], dtype='int64'),
#  264: Int64Index([38446], dtype='int64'),
#  266: Int64Index([38665, 38687, 38781], dtype='int64'),
#  268: Int64Index([38978], dtype='int64'),
#  269: Int64Index([39031], dtype='int64'),
#  270: Int64Index([39060], dtype='int64'),
#  273: Int64Index([39174, 39192], dtype='int64'),
#  274: Int64Index([39229, 39230, 39288, 39448, 39549], dtype='int64'),
#  275: Int64Index([40575, 40596, 40749], dtype='int64'),
#  276: Int64Index([40978, 40979], dtype='int64'),
#  277: Int64Index([41019], dtype='int64'),
#  279: Int64Index([41067, 41072], dtype='int64'),
#  280: Int64Index([41243], dtype='int64'),
#  282: Int64Index([41460, 41472, 41533], dtype='int64'),
#  283: Int64Index([41697], dtype='int64'),
#  284: Int64Index([41732, 41770], dtype='int64'),
#  285: Int64Index([41821, 41842], dtype='int64'),
#  286: Int64Index([41866], dtype='int64'),
#  287: Int64Index([42018], dtype='int64'),
#  288: Int64Index([42114, 42115, 42150, 42438], dtype='int64'),
#  290: Int64Index([43193, 43209], dtype='int64'),
#  291: Int64Index([43460], dtype='int64'),
#  292: Int64Index([43491, 43505, 43586], dtype='int64'),
#  293: Int64Index([43937], dtype='int64'),
#  294: Int64Index([43958, 43990, 44184], dtype='int64'),
#  295: Int64Index([44399], dtype='int64'),
#  296: Int64Index([44438], dtype='int64'),
#  298: Int64Index([44535, 44536, 44555, 44620, 44655], dtype='int64'),
#  299: Int64Index([45474], dtype='int64'),
#  301: Int64Index([45542], dtype='int64'),
#  302: Int64Index([45657], dtype='int64'),
#  304: Int64Index([45728, 45729, 45768], dtype='int64'),
#  305: Int64Index([45944, 45962, 46076], dtype='int64'),
#  307: Int64Index([46733, 46734, 46790, 47011], dtype='int64'),
#  308: Int64Index([47708], dtype='int64'),
#  309: Int64Index([47824], dtype='int64'),
#  313: Int64Index([48261, 48336, 48389], dtype='int64'),
#  314: Int64Index([48581, 48632], dtype='int64'),
#  484: Int64Index([77950, 77951, 78032], dtype='int64'),
#  486: Int64Index([78273], dtype='int64'),
#  488: Int64Index([78360], dtype='int64'),
#  489: Int64Index([78471, 78512, 78699], dtype='int64'),
#  490: Int64Index([79119, 79124], dtype='int64'),
#  492: Int64Index([79296], dtype='int64'),
#  497: Int64Index([79794], dtype='int64'),
#  498: Int64Index([79860], dtype='int64'),
#  500: Int64Index([79907, 79942, 79957], dtype='int64'),
#  501: Int64Index([79993], dtype='int64'),
#  503: Int64Index([80075, 80102], dtype='int64'),
#  504: Int64Index([80168, 80171, 80184], dtype='int64'),
#  509: Int64Index([80373, 80387], dtype='int64'),
#  512: Int64Index([81000, 81017], dtype='int64'),
#  513: Int64Index([81057], dtype='int64'),
#  514: Int64Index([81082, 81096, 81190], dtype='int64'),
#  517: Int64Index([81531, 81532], dtype='int64'),
#  519: Int64Index([81958], dtype='int64'),
#  522: Int64Index([82207, 82216], dtype='int64'),
#  523: Int64Index([82407], dtype='int64'),
#  524: Int64Index([82482], dtype='int64'),
#  525: Int64Index([82613, 82614, 82713], dtype='int64'),
#  526: Int64Index([83114], dtype='int64'),
#  527: Int64Index([83171, 83241], dtype='int64'),
#  528: Int64Index([83338, 83341], dtype='int64'),
#  529: Int64Index([83411], dtype='int64'),
#  533: Int64Index([83535], dtype='int64'),
#  534: Int64Index([83573, 83574], dtype='int64'),
#  540: Int64Index([84288], dtype='int64'),
#  541: Int64Index([84327], dtype='int64'),
#  542: Int64Index([84417], dtype='int64'),
#  544: Int64Index([84603], dtype='int64'),
#  550: Int64Index([84780], dtype='int64'),
#  551: Int64Index([84812], dtype='int64'),
#  552: Int64Index([84939], dtype='int64'),
#  553: Int64Index([85127], dtype='int64'),
#  555: Int64Index([85291, 85325, 85541], dtype='int64'),
#  558: Int64Index([85930, 85944], dtype='int64'),
#  559: Int64Index([85984, 85985, 86029], dtype='int64'),
#  560: Int64Index([86124, 86140, 86177], dtype='int64'),
#  561: Int64Index([86582, 86583, 86601, 86710], dtype='int64'),
#  562: Int64Index([87087, 87093, 87147], dtype='int64'),
#  563: Int64Index([87318, 87347], dtype='int64'),
#  564: Int64Index([87542], dtype='int64'),
#  565: Int64Index([87698], dtype='int64'),
#  566: Int64Index([87717, 87748], dtype='int64'),
#  567: Int64Index([87791, 87815], dtype='int64'),
#  568: Int64Index([88178], dtype='int64'),
#  569: Int64Index([88205], dtype='int64'),
#  570: Int64Index([88219, 88220, 88341], dtype='int64'),
#  572: Int64Index([88522], dtype='int64'),
#  573: Int64Index([88677, 88678, 88693], dtype='int64'),
#  574: Int64Index([88985], dtype='int64'),
#  575: Int64Index([88999], dtype='int64'),
#  577: Int64Index([89155], dtype='int64'),
#  579: Int64Index([89243], dtype='int64'),
#  580: Int64Index([89316, 89339], dtype='int64'),
#  583: Int64Index([89852], dtype='int64'),
#  584: Int64Index([89904, 89945], dtype='int64'),
#  585: Int64Index([89992], dtype='int64'),
#  586: Int64Index([90048], dtype='int64'),
#  587: Int64Index([90256, 90268], dtype='int64'),
#  588: Int64Index([90451], dtype='int64'),
#  589: Int64Index([90488], dtype='int64'),
#  590: Int64Index([90517, 90518, 90546], dtype='int64'),
#  592: Int64Index([91299, 91335], dtype='int64'),
#  593: Int64Index([91443], dtype='int64'),
#  594: Int64Index([91496], dtype='int64'),
#  596: Int64Index([91748, 91832], dtype='int64'),
#  597: Int64Index([92159, 92419], dtype='int64'),
#  599: Int64Index([92623, 92624, 92742, 93073, 93269], dtype='int64'),
#  600: Int64Index([95101, 95102, 95154, 95306], dtype='int64'),
#  601: Int64Index([95864], dtype='int64'),
#  602: Int64Index([95965, 96029], dtype='int64'),
#  603: Int64Index([96100, 96171, 96414], dtype='int64'),
#  604: Int64Index([97043, 97044, 97103], dtype='int64'),
#  605: Int64Index([97143, 97144, 97151], dtype='int64'),
#  606: Int64Index([97364, 97418, 97592, 97692], dtype='int64'),
#  607: Int64Index([98479, 98496, 98574], dtype='int64'),
#  608: Int64Index([98666, 98667, 98723, 98882, 98980], dtype='int64'),
#  609: Int64Index([99497, 99510], dtype='int64'),
#  610: Int64Index([99534, 99552, 99636, 99664], dtype='int64')}

# %%
# Classificando para que os usuários com filme mais em comum com a entrada tenham prioridade
userSubsetGroup = sorted(userSubsetGroup,  key=lambda x: len(x[1]), reverse=True)

# %%
userSubsetGroup[0:3]
# Out:
# [(91,        userId  movieId  rating
#   14121      91        1     4.0
#   14122      91        2     3.0
#   14173      91      296     4.5
#   14316      91     1274     5.0
#   14383      91     1968     3.0), (177,        userId  movieId  rating
#   24900     177        1     5.0
#   24901     177        2     3.5
#   24930     177      296     5.0
#   25069     177     1274     2.0
#   25129     177     1968     3.5), (219,        userId  movieId  rating
#   31524     219        1     3.5
#   31525     219        2     2.5
#   31554     219      296     4.0
#   31628     219     1274     2.5
#   31680     219     1968     3.0)]

# %% [markdown]
# ## Similaridade dos usuários para o usuário de entrada

# %% [markdown]
# Em seguida, vamos comparar todos os usuários (não todos !!!) ao nosso usuário especificado e encontrar aquele que é mais semelhante.
# Vamos descobrir como cada usuário é semelhante à entrada por meio do coeficiente de correlação de Pearson, que é usado para medir a força de uma associação linear entre duas variáveis.

# %% [markdown]
# ### Por que a correlação de Pearson?

# %% [markdown]
# A correlação de Pearson é invariante ao escalonamento, isto é, multiplicando todos os elementos por uma constante diferente de zero ou adicionando qualquer constante a todos os elementos.
#
# Por exemplo, se você tem dois vetores X e Y, então, pearson (X, Y) == pearson (X, 2 * Y + 3).
#
# Esta é uma propriedade muito importante nos sistemas de recomendação porque, por exemplo, dois usuários podem classificar duas séries de itens totalmente diferentes em termos de taxas absolutas, mas seriam usuários semelhantes (ou seja, com idéias semelhantes) com taxas semelhantes em várias escalas.

# %% [markdown]
# Os valores fornecidos pela fórmula variam de r = -1 a r = 1, onde 1 forma uma correlação direta entre as duas entidades (significa uma correlação positiva perfeita) e -1 forma uma correlação negativa perfeita.
#
# No nosso caso, um 1 significa que os dois usuários têm gostos semelhantes, enquanto -1 significa o oposto.

# %%
# Posso impor um limite por onde iremos percorrer, para que não precisaremos passar por todos
#userSubsetGroup = userSubsetGroup[0:100]

# %%
# Armazene a Correlação de Pearson em um dicionário, em que a chave é o ID do usuário e o valor é o coeficiente
correlacaoPearson = {}
#Percorrer os usuários no dataset
for name, group in userSubsetGroup:
    # Vamos começar classificando a entrada e o grupo de usuários atual para que os valores não sejam misturados mais tarde
    group = group.sort_values(by='movieId')
    inputMovies = inputMovies.sort_values(by='movieId')
    #Pegando o N da formula
    nNotas = len(group)
    #Pegando os filmes que tem em comum
    temp_df = inputMovies[inputMovies['movieId'].isin(group.movieId.tolist())]
    temp_notas = temp_df['rating'].tolist()
    temp_group = group['rating'].tolist()
    #Agora vamos calcular a Correlação de Pearson entre 2 usuários, chamados X e Y
    Sxx = sum([i**2 for i in temp_notas]) - pow(sum(temp_notas),2)/float(nNotas)
    Syy = sum([i**2 for i in temp_group]) - pow(sum(temp_group),2)/float(nNotas)
    Sxy = sum( i*j for i, j in zip(temp_notas, temp_group)) - sum(temp_notas)*sum(temp_group)/float(nNotas)
    #Se o denominador for diferente de 0 então divida.
    if Sxx != 0 and Syy != 0:
        correlacaoPearson[name] = Sxy/sqrt(Sxx*Syy)
    else:
        correlacaoPearson[name] = 0

# %%
correlacaoPearson.items()
# Out:
# dict_items([(91, 0.43852900965351443), (177, 0.0), (219, 0.45124262819713973), (274, 0.716114874039432), (298, 0.9592712306918567), (414, 0.9376144618769914), (474, 0.11720180773462392), (477, 0.4385290096535153), (480, 0.7844645405527362), (483, 0.08006407690254357), (599, 0.7666866491579839), (608, 0.920736884379251), (50, 0.15713484026367722), (57, -0.7385489458759964), (68, 0.0), (103, 0.5222329678670935), (135, 0.8703882797784892), (182, 0.9428090415820635), (202, 0.5222329678670935), (217, 0.30151134457776363), (226, 0.9438798074485389), (288, 0.6005325641789633), (307, 0.9655810287305759), (318, 0.44486512077567225), (322, 0.5057805388588731), (330, 0.9035942578600878), (357, 0.5606119105813882), (434, 0.9864036607532465), (448, 0.30151134457776363), (469, 0.8164965809277261), (561, 0.5222329678670935), (600, 0.18442777839082938), (606, 0.9146591207600472), (610, -0.47140452079103173), (18, 1.0), (19, -0.5), (21, 0), (45, 0.5000000000000009), (63, -0.4999999999999982), (64, 0.0), (66, 0.5000000000000009), (107, -1.0), (122, 0.8660254037844387), (132, 1.0000000000000004), (140, 0.5), (141, 0), (144, 1.0), (153, 0.8660254037844379), (156, 0.1889822365046138), (160, 0.8660254037844402), (166, -0.6546536707079772), (198, 0.0), (200, 0.7559289460184552), (201, 0), (232, 0.6546536707079778), (240, -0.8660254037844386), (249, 0), (266, 0.5), (275, -0.4999999999999982), (282, -1.000000000000007), (292, -1.0000000000000018), (294, 0.5000000000000009), (304, 0.8660254037844356), (305, 1.0), (313, -0.4999999999999929), (323, 0.0), (328, -0.5000000000000002), (353, 0.8660254037844356), (359, 0.8660254037844448), (372, 0.142857142857144), (373, 0.866025403784439), (380, 0), (381, 0.6546536707079778), (387, -0.18
# 0      0.438529      91
# 1      0.000000     177
# 2      0.451243     219
# 3      0.716115     274
# 4      0.959271     298

# %%
topUsers=pearsonDF.sort_values(by='Similaridade', ascending=False)[0:50]
topUsers.head()
# Out:
#      Similaridade  userId
# 43            1.0     132
# 181           1.0     382
# 219           1.0     602
# 130           1.0     130
# 129           1.0     125

# %%
#Agora vamos multiplicar pelo peso das notas.
topUsersRating=topUsers.merge(df_notas, left_on='userId', right_on='userId', how='inner')
topUsersRating.head()
# Out:
#    Similaridade  userId  movieId  rating
# 0           1.0     132        1     2.0
# 1           1.0     132       17     3.0
# 2           1.0     132       29     2.0
# 3           1.0     132       32     3.0
# 4           1.0     132       34     1.5

# %%
topUsersRating['peso'] = topUsersRating['Similaridade']*topUsersRating['rating']
topUsersRating.head()
# Out:
#    Similaridade  userId  movieId  rating  peso
# 0           1.0     132        1     2.0   2.0
# 1           1.0     132       17     3.0   3.0
# 2           1.0     132       29     2.0   2.0
# 3           1.0     132       32     3.0   3.0
# 4           1.0     132       34     1.5   1.5

# %%
#Aplica uma soma aos principais usuários após agrupá-lo por userId
tempTopUsersRating = topUsersRating.groupby('movieId').sum()[['Similaridade','peso']]
tempTopUsersRating.columns = ['sum_similaridade','sum_peso']
tempTopUsersRating.head()
# Out:
#          sum_similaridade  sum_peso
# movieId
# 1                    36.0     124.0
# 2                    18.0      58.0
# 3                     3.0      11.0
# 5                     3.0       8.5
# 6                    13.0      49.5

# %%
#Criar dataframe novo
recommendation_df = pd.DataFrame()
#Agora pegamos a média dos pesos
recommendation_df['Média do peso da similaridade'] = tempTopUsersRating['sum_peso']/tempTopUsersRating['sum_similaridade']
recommendation_df['movieId'] = tempTopUsersRating.index
recommendation_df.head()
# Out:
#          Média do peso da similaridade  movieId
# movieId
# 1                             3.444444        1
# 2                             3.222222        2
# 3                             3.666667        3
# 5                             2.833333        5
# 6                             3.807692        6

# %%
recommendation_df = recommendation_df.sort_values(by='Média do peso da similaridade', ascending=False)
recommendation_df.head(10)
# Out:
#          Média do peso da similaridade  movieId
# movieId
# 3035                               5.0     3035
# 1956                               5.0     1956
# 2522                               5.0     2522
# 2495                               5.0     2495
# 2477                               5.0     2477
# 163386                             5.0   163386
# 2455                               5.0     2455
# 2450                               5.0     2450
# 2427                               5.0     2427
# 163112                             5.0   163112

# %%
df_filmes.loc[df_filmes['movieId'].isin(recommendation_df.head(10)['movieId'].tolist())]
# Out:
#       movieId                                        title  year
# 1433     1956                              Ordinary People  1980
# 1826     2427                           Thin Red Line, The  1998
# 1842     2450                              Howard the Duck  1986
# 1846     2455                                     Fly, The  1986
# 1865     2477                                   Firewalker  1986
# 1877     2495  Fantastic Planet, The (Planète sauvage, La)  1973
# 1898     2522                                  Airport '77  1977
# 2288     3035                               Mister Roberts  1955
# 9380   163112                Winnie the Pooh Goes Visiting  1971
# 9382   163386       Winnie the Pooh and the Day of Concern  1972

# %%
# Out:
# '[alt' não é reconhecido como um comando interno
# ou externo, um programa operável ou um arquivo em lotes.
